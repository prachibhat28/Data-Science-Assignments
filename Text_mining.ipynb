# %%
#Text mining .. Elon musk data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from nltk.corpus import stopwords
from textblob import TextBlob

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-ac094ebe-9b22-449c-9ad8-4bdd231d59d5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ac094ebe-9b22-449c-9ad8-4bdd231d59d5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('Elon_musk.csv',encoding="latin-1")
data.head()
# Out:
#    Unnamed: 0                                               Text
# 0           1                             @kunalb11 Im an alien
# 1           2  @ID_AA_Carmack Ray tracing on Cyberpunk with H...
# 2           3                @joerogan @Spotify Great interview!
# 3           4                    @gtera27 Doge is underestimated
# 4           5  @teslacn Congratulations Tesla China for amazi...

# %%
data['word_count'] = data['Text'].apply(lambda x: len(str(x).split(" ")))
data[['Text','word_count']].head()
# Out:
#                                                 Text  word_count
# 0                             @kunalb11 Im an alien           4
# 1  @ID_AA_Carmack Ray tracing on Cyberpunk with H...          13
# 2                @joerogan @Spotify Great interview!           4
# 3                    @gtera27 Doge is underestimated           4
# 4  @teslacn Congratulations Tesla China for amazi...          17

# %%
data['char_count'] = data['Text'].str.len() ## this also includes spaces
data[['Text','char_count']].head()
# Out:
#                                                 Text  char_count
# 0                             @kunalb11 Im an alien          22
# 1  @ID_AA_Carmack Ray tracing on Cyberpunk with H...          82
# 2                @joerogan @Spotify Great interview!          35
# 3                    @gtera27 Doge is underestimated          31
# 4  @teslacn Congratulations Tesla China for amazi...         104

# %%
def avg_word(sentence):
  words = sentence.split()
  return (sum(len(word) for word in words)/len(words))

data['avg_word'] = data['Text'].apply(lambda x: avg_word(x))
data[['Text','avg_word']].head()
# Out:
#                                                 Text  avg_word
# 0                             @kunalb11 Im an alien  4.750000
# 1  @ID_AA_Carmack Ray tracing on Cyberpunk with H...  5.384615
# 2                @joerogan @Spotify Great interview!  8.000000
# 3                    @gtera27 Doge is underestimated  7.000000
# 4  @teslacn Congratulations Tesla China for amazi...  5.176471

# %%
def stop_word(sentence):
  words = sentence.split()
  return (sum(len(word) for word in words)/len(words))
  
  stop = stopwords.words('english')

data['stop_words'] = data['Text'].apply(lambda x: stop_word(x))
data[['Text','stop_words']].head()
# Out:
#                                                 Text  stop_words
# 0                             @kunalb11 Im an alien    4.750000
# 1  @ID_AA_Carmack Ray tracing on Cyberpunk with H...    5.384615
# 2                @joerogan @Spotify Great interview!    8.000000
# 3                    @gtera27 Doge is underestimated    7.000000
# 4  @teslacn Congratulations Tesla China for amazi...    5.176471

# %%
data['hastags'] = data['Text'].apply(lambda x: len([x for x in x.split() if x.startswith('@')]))
data[['Text','hastags']].head()
# Out:
#                                                 Text  hastags
# 0                             @kunalb11 Im an alien        1
# 1  @ID_AA_Carmack Ray tracing on Cyberpunk with H...        1
# 2                @joerogan @Spotify Great interview!        2
# 3                    @gtera27 Doge is underestimated        1
# 4  @teslacn Congratulations Tesla China for amazi...        1

# %%
data['numerics'] = data['Text'].apply(lambda x: len([x for x in x.split() if x.isdigit()]))
data[['Text','numerics']].head()
# Out:
#                                                 Text  numerics
# 0                             @kunalb11 Im an alien         0
# 1  @ID_AA_Carmack Ray tracing on Cyberpunk with H...         0
# 2                @joerogan @Spotify Great interview!         0
# 3                    @gtera27 Doge is underestimated         0
# 4  @teslacn Congratulations Tesla China for amazi...         0

# %%
data['upper'] = data['Text'].apply(lambda x: len([x for x in x.split() if x.isupper()]))
data[['Text','upper']].head()
# Out:
#                                                 Text  upper
# 0                             @kunalb11 Im an alien      0
# 1  @ID_AA_Carmack Ray tracing on Cyberpunk with H...      1
# 2                @joerogan @Spotify Great interview!      0
# 3                    @gtera27 Doge is underestimated      0
# 4  @teslacn Congratulations Tesla China for amazi...      0

# %%
data['Text'] = data['Text'].apply(lambda x: " ".join(x.lower() for x in x.split()))
data['Text'].head()
# Out:
# 0                               @kunalb11 im an alien
# 1    @id_aa_carmack ray tracing on cyberpunk with h...
# 2                  @joerogan @spotify great interview!
# 3                      @gtera27 doge is underestimated
# 4    @teslacn congratulations tesla china for amazi...
# Name: Text, dtype: object

# %%
data['Text'] = data['Text'].str.replace('[^\w\s]','')
data['Text'].head()
# Out:
# <ipython-input-15-5a2099d0f9da>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['Text'] = data['Text'].str.replace('[^\w\s]','')
# 0                                 kunalb11 im an alien
# 1    id_aa_carmack ray tracing on cyberpunk with hd...
# 2                     joerogan spotify great interview
# 3                       gtera27 doge is underestimated
# 4    teslacn congratulations tesla china for amazin...
# Name: Text, dtype: object

# %%
data['Text'] = data['Text'].apply(lambda x: " ".join(x))
data['Text'].head()
# Out:
# 0              k u n a l b 1 1   i m   a n   a l i e n
# 1    i d _ a a _ c a r m a c k   r a y   t r a c i ...
# 2    j o e r o g a n   s p o t i f y   g r e a t   ...
# 3    g t e r a 2 7   d o g e   i s   u n d e r e s ...
# 4    t e s l a c n   c o n g r a t u l a t i o n s ...
# Name: Text, dtype: object

# %%
freq = pd.Series(' '.join(data['Text']).split()).value_counts()[:10]
freq
# Out:
# e    12549
# t    11653
# a    10649
# o     8800
# s     8688
# i     7582
# n     7303
# r     7297
# l     5886
# h     5112
# dtype: int64

# %%
data['Text'] = data['Text'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
data['Text'].head()
# Out:
# 0                                        k u b 1 1 m
# 1    d _ _ c m c k y c g c y b p u k w d x v v y u d
# 2                                    j g p f y g v w
# 3                                  g 2 7 d g u d m d
# 4                c c g u c f m z g x c u y w x f v m
# Name: Text, dtype: object

# %%
freq = pd.Series(' '.join(data['Text']).split()).value_counts()[-10:]
freq
# Out:
# 7    196
# ö      6
# ü      4
# ø      2
# é      2
# ð      2
# è      1
# ä      1
# ß      1
# à      1
# dtype: int64

# %%
data['Text'] = data['Text'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
data['Text'].head()
# Out:
# 0                                        k u b 1 1 m
# 1    d _ _ c m c k y c g c y b p u k w d x v v y u d
# 2                                    j g p f y g v w
# 3                                    g 2 d g u d m d
# 4                c c g u c f m z g x c u y w x f v m
# Name: Text, dtype: object

# %%
import codecs
import re
import copy
import collections
import pandas as pd
import numpy as np
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import WordPunctTokenizer
import matplotlib

# %%
# %matplotlib inline
from __future__ import division
import os
from nltk.corpus import twitter_samples

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-0570ea1d-748b-4de8-8a6a-e5860ef7baad" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0570ea1d-748b-4de8-8a6a-e5860ef7baad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from nltk.corpus import stopwords
with codecs.open("positive-words.txt", "r", encoding="utf-8") as p:
    pos = p.read()
    print(pos)
# Out:
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;
# ; Opinion Lexicon: Positive
# ;
# ; This file contains a list of POSITIVE opinion words (or sentiment words).
# ;
# ; This file and the papers can all be downloaded from
# ;    http://www.cs.uic.edu/~liub/FBS/sentiment-analysis.html
# ;
# ; If you use this list, please cite one of the following two papers:
# ;
# ;   Minqing Hu and Bing Liu. "Mining and Summarizing Customer Reviews."
# ;       Proceedings of the ACM SIGKDD International Conference on Knowledge
# ;       Discovery and Data Mining (KDD-2004), Aug 22-25, 2004, Seattle,
# ;       Washington, USA,
# ;   Bing Liu, Minqing Hu and Junsheng Cheng. "Opinion Observer: Analyzing
# ;       and Comparing Opinions on the Web." Proceedings of the 14th
# ;       International World Wide Web conference (WWW-2005), May 10-14,
# ;       2005, Chiba, Japan.
# ;
# ; Notes:
# ;    1. The appearance of an opinion word in a sentence does not necessarily
# ...

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-c59b14f3-036f-4c21-a573-32c7304501c7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c59b14f3-036f-4c21-a573-32c7304501c7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
with codecs.open("negative-words.txt", "r", encoding="ISO-8859-1") as n:
    neg = n.read()
    print(neg)
# Out:
# ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# ;
# ; Opinion Lexicon: Negative
# ;
# ; This file contains a list of NEGATIVE opinion words (or sentiment words).
# ;
# ; This file and the papers can all be downloaded from
# ;    http://www.cs.uic.edu/~liub/FBS/sentiment-analysis.html
# ;
# ; If you use this list, please cite one of the following two papers:
# ;
# ;   Minqing Hu and Bing Liu. "Mining and Summarizing Customer Reviews."
# ;       Proceedings of the ACM SIGKDD International Conference on Knowledge
# ;       Discovery and Data Mining (KDD-2004), Aug 22-25, 2004, Seattle,
# ;       Washington, USA,
# ;   Bing Liu, Minqing Hu and Junsheng Cheng. "Opinion Observer: Analyzing
# ;       and Comparing Opinions on the Web." Proceedings of the 14th
# ;       International World Wide Web conference (WWW-2005), May 10-14,
# ;       2005, Chiba, Japan.
# ;
# ; Notes:
# ;    1. The appearance of an opinion word in a sentence does not necessarily
# ...

# %%
from nltk.corpus import twitter_samples

positive_tweets = ('positive_tweets.json')
negative_tweets = ('negative_tweets.json')

# %%
text =('tweets.20150430-223406.json')

# %%
import nltk
nltk.download('punkt')

from nltk.corpus import twitter_samples
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
from nltk.corpus import twitter_samples

# %%
positive_tweets =('positive_tweets.json')
negative_tweets =('negative_tweets.json')
text =('tweets.20150430-223406.json')
tweet_tokens =('positive_tweets.json')
from nltk.corpus import twitter_samples

# %%
positive_tweets =('positive_tweets.json')
negative_tweets =('negative_tweets.json')
text =('tweets.20150430-223406.json')
tweet_tokens =('positive_tweets.json')[0]

# %%
print(tweet_tokens[0])
# Out:
# p
